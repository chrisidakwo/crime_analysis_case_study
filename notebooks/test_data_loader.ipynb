# %%
from src.data.loader import DataLoader

loader = DataLoader()

# %%
summary = loader.dataset_summary()
print(summary)
# Out:
#    total_incidents  earliest_year  latest_year  crime_types  districts  \
# 0           100000           2001         2025           33         23
#
#    community_areas total_arrests arrest_rate total_domestic_incidents
# 0               78         13946       13.95                    16627

# %%
crime_lists = loader.get_crime_type_list()
print(crime_lists)
# Out:
#                          primary_type  total_incidents
# 0                               THEFT            22261
# 1                             BATTERY            15576
# 2                  DECEPTIVE PRACTICE             9512
# 3                     CRIMINAL DAMAGE             9477
# 4                 MOTOR VEHICLE THEFT             8946
# 5                             ASSAULT             7765
# 6                       OTHER OFFENSE             5511
# 7                             ROBBERY             4932
# 8                           NARCOTICS             3116
# 9                            BURGLARY             2985
# 10                  WEAPONS VIOLATION             2378
# 11                  CRIMINAL TRESPASS             1582
# 12         OFFENSE INVOLVING CHILDREN             1484
# 13            CRIMINAL SEXUAL ASSAULT             1246
# 14                           HOMICIDE              963
# 15                        SEX OFFENSE              908
# ...

# %%
yearly_crime_trend = loader.get_annual_crime_counts()
print(yearly_crime_trend)
# Out:
#     year  total_incidents
# 0   2001             2050
# 1   2002             1497
# 2   2003              402
# 3   2004              466
# 4   2005              554
# 5   2006              335
# 6   2007              319
# 7   2008              514
# 8   2009              466
# 9   2010              268
# 10  2011              346
# 11  2012              298
# 12  2013              296
# 13  2014              405
# 14  2015              621
# 15  2016              573
# 16  2017              725
# 17  2018              751
# 18  2019              688
# 19  2020             1065
# 20  2021             1617
# 21  2022             4008
# 22  2023            80837
# 23  2024              812
# 24  2025               87
