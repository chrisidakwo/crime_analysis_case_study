# %%
from src.database.connector import DatabaseConnector

db = DatabaseConnector()

df = db.query("SELECT primary_type, COUNT(*) as total FROM incidents GROUP BY primary_type ORDER BY total DESC")

print(df.head(10))
